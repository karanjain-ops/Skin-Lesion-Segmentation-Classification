# %%
# Import required moduls/libs for our model
import numpy as np          # linear algebra
import pandas as pd         # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import keras
from keras.models import Sequential, load_model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.core import Dropout, Activation
from keras.layers import Conv2D, BatchNormalization, MaxPool2D, Flatten, \
     Dense, Input, Activation, Dropout, GlobalAveragePooling2D, AveragePooling2D
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.models import Model
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
import cv2
from cv2 import imread, resize # manipulating the images
from tensorflow.keras.optimizers import Adam
import os

# %%
# Reading the meta date of our data frame.
df_skin = pd.read_csv('skin-cancer-mnist-ham10000/HAM10000_metadata.csv')
# Display the first 10 lines
df_skin.head(10)
# Out:
#      lesion_id      image_id   dx dx_type   age     sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0    male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0    male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0    male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0    male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0    male          ear
# 5  HAM_0001466  ISIC_0027850  bkl   histo  75.0    male          ear
# 6  HAM_0002761  ISIC_0029176  bkl   histo  60.0    male         face
# 7  HAM_0002761  ISIC_0029068  bkl   histo  60.0    male         face
# 8  HAM_0005132  ISIC_0025837  bkl   histo  70.0  female         back
# 9  HAM_0005132  ISIC_0025209  bkl   histo  70.0  female         back

# %%
# Lesion/dis names are given in the description of the data set.
lesion_type_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'Melanoma',
    'bkl': 'Benign keratosis-like lesions ',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

lesion_ID_dict = {
    'nv': 0,
    'mel': 1,
    'bkl': 2,
    'bcc': 3,
    'akiec': 4,
    'vasc': 5,
    'df': 6
}

# Lesion and it's abbriv.
lesion_names = ['Melanocytic nevi','Melanoma','Benign keratosis-like lesions ',
               'Basal cell carcinoma','Actinic keratoses','Vascular lesions',
               'Dermatofibroma']
lesion_names_short = ['nv','mel','bkl','bcc','akiec','vasc','df']

# Maping the lesion type and ID to a dict.
df_skin['lesion_type']=df_skin['dx'].map(lesion_type_dict)
df_skin['lesion_ID'] = df_skin['dx'].map(lesion_ID_dict)

# Display the total found images.
print('Total number of images', len(df_skin))
print('The problem is unbalanced, since Melanocytic nevi is much more frequent that other labels')

# Display the count of each lesion.
df_skin['lesion_type'].value_counts()
# Out:
# Total number of images 10015
# The problem is unbalanced, since Melanocytic nevi is much more frequent that other labels
# Melanocytic nevi                  6705
# Melanoma                          1113
# Benign keratosis-like lesions     1099
# Basal cell carcinoma               514
# Actinic keratoses                  327
# Vascular lesions                   142
# Dermatofibroma                     115
# Name: lesion_type, dtype: int64

# %%
# Reading a random image from our data set
fname_images = np.array(df_skin['image_id'])
file_to_read ='skin-cancer-mnist-ham10000/HAM10000_images_part_1/'+str(fname_images[13])+'.jpg'

# Resizing the read image to 100x100
img = imread(file_to_read)
img2 = resize(img, (100, 100))

# Show one exampe image before and after
plt.figure(figsize = (10, 5))
plt.subplot(1, 2, 1)
plt.imshow(img[:, :, ::-1])
plt.title('Original image')
plt.subplot(1, 2, 2)
plt.imshow(img2[:, :, ::-1])
plt.title('Resized image for DenseNet')
plt.show()

# %%
def produce_new_img(img2: cv2) -> tuple:
    """
    function to reproduse a new manipulated (rotating of flipping the original one)
    image from the read one, To increase the dimension of the dataset, avoiding overfitting of a single class.

    Args:
        img2 (cv2): the read image from cv2 module.

    Returns:
        new_images (tuple): a tuple of the new manipulated images.
    """
    imga = cv2.rotate(img2, cv2.ROTATE_90_CLOCKWISE)
    imgb = cv2.rotate(img2, cv2.ROTATE_90_COUNTERCLOCKWISE)
    imgc = cv2.rotate(img2, cv2.ROTATE_180)
    imgd = cv2.flip(img2, 0)
    imge = cv2.flip(img2, 1)
    new_imges = imga, imgb, imgc, imgd ,imge
    return new_imges

def show_example() -> None:
    """
    Display an image after manipulating it in produce_new_img() function
    """
    plt.figure(figsize = (10, 8))
    plt.subplot(2, 3, 1)
    plt.imshow(img2[:, :, ::-1])
    for i in range(5):
        plt.subplot(2, 3, 2+i)
        plt.imshow(new_img[i][:, :, ::-1])
    plt.tight_layout()
    plt.show()

# Invoking our function :)
new_img = produce_new_img(img2)
# Display an example by invoking show_example func
show_example()

# %%
x = []          # Hold resized images.
y = []          # Hold image lesion ID from the data set.

# Listing all files in the part_1, part_2 dirs
lista1 = os.listdir('skin-cancer-mnist-ham10000/HAM10000_images_part_1/')
lista2 = os.listdir('skin-cancer-mnist-ham10000/HAM10000_images_part_2/')

# [+] Handling images from part 1 directory
for i in range(len(lista1)):
    # [+] Features: reading and resize the photo.
    fname_image = lista1[i]
    fname_ID = fname_image.replace('.jpg', '')
    file_to_read ='skin-cancer-mnist-ham10000/HAM10000_images_part_1/' + str(fname_image)  # resolve image name
    img = imread(file_to_read)                                  # read the image 
    img2 = resize(img,(100, 100))                               # resise our image
    x.append(img2)                                              # append the new image to the list x.
    
    # Targets: Finding the image lesion ID and append it to the y list.
    output = np.array(df_skin[df_skin['image_id'] == fname_ID].lesion_ID)
    y.append(output[0])
    
    # add more images for class between 1-6, rotating them 
    if output != 0:
        new_img = produce_new_img(img2)
        for i in range(5):
            x.append(new_img[i])
            y.append(output[0])

    # inform the user with the number of loaded images each 100 img.
    if i % 100 == 0:
        print(i, 'images loaded')


# [+] Handling images from part 2 directory
for i in range(len(lista2)):

    # [+] Features: reading and resize the photo.
    fname_image = lista2[i]
    fname_ID = fname_image.replace('.jpg', '')
    file_to_read ='skin-cancer-mnist-ham10000/HAM10000_images_part_2/' + str(fname_image)


    img = imread(file_to_read)
    img2 = resize(img, (100, 100))
    x.append(img2)
    
    # Targets: Finding the image lesion ID and append it to the y list.
    output = np.array(df_skin[df_skin['image_id'] == fname_ID].lesion_ID)
    y.append(output[0])
    
    # [+] Add more images for class between 1-6
    if output != 0:
        new_img = produce_new_img(img2)
        for i in range(5):
            x.append(new_img[i])
            y.append(output[0])
    
    if i % 100 == 0: # [+] Inform the user with the number of loaded images each 100 img.
        print(len(lista1) + i,'images loaded')
# Out:
# 0 images loaded
# 100 images loaded
# 200 images loaded
# 300 images loaded
# 600 images loaded
# 700 images loaded
# 800 images loaded
# 900 images loaded
# 1000 images loaded
# 1100 images loaded
# 1200 images loaded
# 1400 images loaded
# 1500 images loaded
# 1700 images loaded
# 1800 images loaded
# 2000 images loaded
# 2100 images loaded
# 2400 images loaded
# 2500 images loaded
# 2600 images loaded
# 2800 images loaded
# 2900 images loaded
# 3100 images loaded
# 3600 images loaded
# 3700 images loaded
# 3900 images loaded
# 4200 images loaded
# 4300 images loaded
# 4400 images loaded
# 4500 images loaded
# 4600 images loaded
# 4700 images loaded
# 4800 images loaded
# 5000 images loaded
# 5200 images loaded
# 5400 images loaded
# 5500 images loaded
# 5600 images loaded
# 5700 images loaded
# 5900 images loaded
# 6000 images loaded
# 6100 images loaded
# 6200 images loaded
# 6600 images loaded
# 6700 images loaded
# 6800 images loaded
# 6900 images loaded
# 7000 images loaded
# 7300 images loaded
# 7500 images loaded
# 7600 images loaded
# 7800 images loaded
# 8100 images loaded
# 8200 images loaded
# 8300 images loaded
# 8400 images loaded
# 8700 images loaded
# 8800 images loaded
# 9100 images loaded
# 9200 images loaded
# 9400 images loaded
# 9600 images loaded
# 9900 images loaded

# %%
x = np.array(x)
y = np.array(y)

# convert y (targets) array as required by softmax activation function
y_train = to_categorical(y, num_classes = 7)

# %%
# split in 80% training and 20% test data
X_train, X_test, y_train, y_test = train_test_split(x,                  # Images array.
                                                    y_train,            # The training set.
                                                    test_size = 0.20,   # Split data set into 20/80.
                                                    random_state = 50,  # Shuffling number to random the set.
                                                    stratify = y)       # Mix training and test sets.
# [+] Display the count of train/test data set.
print('Train dataset shape', X_train.shape)
print('Test dataset shape', X_test.shape)
# Out:
# Train dataset shape (21252, 100, 100, 3)
# Test dataset shape (5313, 100, 100, 3)

# %%
def show_neg_figuers() -> None:
    """ Display negative figuers of the classes. """
    # Figure, Axes
    _, ax = plt.subplots(1, 7, figsize = (30, 30))
    for i in range(7):
        ax[i].set_axis_off()                                    # set the image to negative.
        ax[i].imshow(X_train[i])                                # Display the img.
        ax[i].set_title(lesion_names[np.argmax(y_train[i])])    # Set image title.

show_neg_figuers()

# %%
def est_class_weights(dis_id: np.array) -> dict:
    """Estimate class weights for unbalanced datasets.

    Args:
        dis_id (np.array): numpy array of dis IDs

    Returns:
        dict: Estimated class weights for for unbalanced datasets.
    """
    class_weights = np.around(compute_class_weight(class_weight = 'balanced', classes = np.unique(dis_id), y = y), 2)
    class_weights = dict(zip(np.unique(dis_id), class_weights))

y_id = np.array(df_skin['lesion_ID'])
new_class_weights = est_class_weights(y_id)
print('The problem is unbalanced. We need to provide class-weights')
print(new_class_weights)
# Out:
# The problem is unbalanced. We need to provide class-weights
# None

# %%
import keras
from keras.utils.np_utils import to_categorical # used for converting labels to one-hot-encoding
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras import backend as K
import itertools
from tensorflow.keras.layers import BatchNormalization
from keras.utils.np_utils import to_categorical # convert to one-hot-encoding

# %%
model = Sequential()
        
# [+] 1st convolutional layer
model.add(Conv2D(filters = 96,
                kernel_size = (11, 11),
                strides = (4, 4),
                activation = 'relu',
                input_shape = (100, 100, 3)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = (3, 3), strides = (2, 2)))

# [+] 2nd convolutional layer
model.add(Conv2D(filters = 256,
                kernel_size=(5, 5),
                strides=(1, 1),
                activation = 'relu',
                padding = "same"))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = (3, 3), strides = (2, 2)))

# [+] 3rd convolutional layer
model.add(Conv2D(filters = 384,
                 kernel_size=(3,3),
                 strides=(1,1),
                 activation='relu',
                 padding="same"))
model.add(BatchNormalization())

# [+] 4th convolutional layer
model.add(Conv2D(filters = 384,
                kernel_size = (1, 1), 
                strides = (1, 1), 
                activation = 'relu', 
                padding = "same"))
model.add(BatchNormalization())

# [+] 5th convolutional layer
model.add(Conv2D(filters = 256, 
                kernel_size = (1, 1),
                strides = (1, 1),
                activation = 'relu',
                padding = "same"))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = (3, 3), strides = (2, 2)))
              
model.add(Flatten())  # [+] Convert the Conv2D objects into one List.

# [+] 6th, Dense layer:
# From the Docs: 
# A Dense layer feeds all outputs from the previous layer to all its neurons,
# each neuron providing one output to the next layer.
# source: www.stackoverflow.com
model.add(Dense(4096, activation = 'relu'))
model.add(Dropout(0.5))
              
# [+] 7th Dense layer
model.add(Dense(4096, activation = 'relu'))
model.add(Dropout(0.5))
              
# [+] 8th output layer
model.add(Dense(7, activation = 'softmax'))

# %%
##########################
### [+] Training phase ###
##########################

def mod_checkpoint_callback() -> None:
    """
    Saving our model
    
    Returns:
        None: Saving a checkpoint of the model.
    """
    trained_model = ModelCheckpoint(filepath = 'model_100_class.h5',  # result file name
                             save_weights_only = False,     # Save all training results/params.
                             monitor = 'val_accuracy',      # check our model accuracy if it's step forward.
                             mode = 'auto',                 # enable auto save.
                             save_best_only = True,         # if ac_new > ac_old
                             verbose = 1)
    return trained_model

# Montoring the training procces in each epoch.
early_stopping_monitor = EarlyStopping(patience = 100, monitor = 'val_accuracy')

model_checkpoint_callback = mod_checkpoint_callback()

# Estimate the model data if it was big one.
optimizer = Adam(lr = 0.0001, beta_1 = 0.9, beta_2 = 0.999, epsilon = 1e-3)
model.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

datagen = ImageDataGenerator(zoom_range = 0.2, horizontal_flip = True, shear_range = 0.2)
datagen.fit(X_train)

batch_size = 32     # samples in the network at once.
epochs = 100        # epochs number.

# org model result data
history = model.fit(datagen.flow(X_train,y_train),
                    epochs = epochs,
                    batch_size = batch_size,
                    shuffle = True,
                    callbacks = [early_stopping_monitor, model_checkpoint_callback],
                    validation_data = (X_test, y_test),
                    class_weight = new_class_weights
                )
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1147 - accuracy: 0.9608
# Epoch 1: val_accuracy improved from -inf to 0.86674, saving model to model_100_class.h5
# 665/665 [==============================] - 224s 331ms/step - loss: 0.1147 - accuracy: 0.9608 - val_loss: 0.4373 - val_accuracy: 0.8667
# Epoch 2/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1234 - accuracy: 0.9566
# Epoch 2: val_accuracy improved from 0.86674 to 0.87258, saving model to model_100_class.h5
# 665/665 [==============================] - 230s 346ms/step - loss: 0.1234 - accuracy: 0.9566 - val_loss: 0.4650 - val_accuracy: 0.8726
# Epoch 3/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1322 - accuracy: 0.9539
# Epoch 3: val_accuracy improved from 0.87258 to 0.88105, saving model to model_100_class.h5
# 665/665 [==============================] - 239s 359ms/step - loss: 0.1322 - accuracy: 0.9539 - val_loss: 0.3574 - val_accuracy: 0.8810
# Epoch 4/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1393 - accuracy: 0.9510
# Epoch 4: val_accuracy did not improve from 0.88105
# 665/665 [==============================] - 241s 362ms/step - loss: 0.1393 - accuracy: 0.9510 - val_loss: 1.3245 - val_accuracy: 0.6934
# Epoch 5/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1324 - accuracy: 0.9541
# Epoch 5: val_accuracy improved from 0.88105 to 0.90514, saving model to model_100_class.h5
# 665/665 [==============================] - 241s 362ms/step - loss: 0.1324 - accuracy: 0.9541 - val_loss: 0.3366 - val_accuracy: 0.9051
# Epoch 6/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1309 - accuracy: 0.9544
# Epoch 6: val_accuracy did not improve from 0.90514
# 665/665 [==============================] - 242s 364ms/step - loss: 0.1309 - accuracy: 0.9544 - val_loss: 0.4504 - val_accuracy: 0.8564
# Epoch 7/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1285 - accuracy: 0.9563
# Epoch 7: val_accuracy did not improve from 0.90514
# 665/665 [==============================] - 241s 362ms/step - loss: 0.1285 - accuracy: 0.9563 - val_loss: 0.6705 - val_accuracy: 0.8218
# Epoch 8/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1327 - accuracy: 0.9552
# Epoch 8: val_accuracy did not improve from 0.90514
# 665/665 [==============================] - 242s 364ms/step - loss: 0.1327 - accuracy: 0.9552 - val_loss: 0.4136 - val_accuracy: 0.8777
# Epoch 9/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9555
# Epoch 9: val_accuracy did not improve from 0.90514
# 665/665 [==============================] - 243s 365ms/step - loss: 0.1265 - accuracy: 0.9555 - val_loss: 0.3235 - val_accuracy: 0.9025
# Epoch 10/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1195 - accuracy: 0.9581
# Epoch 10: val_accuracy improved from 0.90514 to 0.90834, saving model to model_100_class.h5
# 665/665 [==============================] - 238s 358ms/step - loss: 0.1195 - accuracy: 0.9581 - val_loss: 0.3223 - val_accuracy: 0.9083
# Epoch 11/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1202 - accuracy: 0.9587
# Epoch 11: val_accuracy did not improve from 0.90834
# 665/665 [==============================] - 237s 357ms/step - loss: 0.1202 - accuracy: 0.9587 - val_loss: 1.0551 - val_accuracy: 0.7583
# Epoch 12/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1262 - accuracy: 0.9565
# Epoch 12: val_accuracy did not improve from 0.90834
# 665/665 [==============================] - 238s 358ms/step - loss: 0.1262 - accuracy: 0.9565 - val_loss: 0.5688 - val_accuracy: 0.8391
# Epoch 13/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1202 - accuracy: 0.9585
# Epoch 13: val_accuracy did not improve from 0.90834
# 665/665 [==============================] - 245s 369ms/step - loss: 0.1202 - accuracy: 0.9585 - val_loss: 0.9809 - val_accuracy: 0.7674
# Epoch 14/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1449 - accuracy: 0.9490
# Epoch 14: val_accuracy did not improve from 0.90834
# 665/665 [==============================] - 253s 381ms/step - loss: 0.1449 - accuracy: 0.9490 - val_loss: 0.4304 - val_accuracy: 0.8758
# Epoch 15/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1155 - accuracy: 0.9615
# Epoch 15: val_accuracy did not improve from 0.90834
# 665/665 [==============================] - 240s 361ms/step - loss: 0.1155 - accuracy: 0.9615 - val_loss: 0.5477 - val_accuracy: 0.8521
# Epoch 16/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1138 - accuracy: 0.9617
# Epoch 16: val_accuracy improved from 0.90834 to 0.90947, saving model to model_100_class.h5
# 665/665 [==============================] - 240s 360ms/step - loss: 0.1138 - accuracy: 0.9617 - val_loss: 0.2926 - val_accuracy: 0.9095
# Epoch 17/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1272 - accuracy: 0.9551
# Epoch 17: val_accuracy did not improve from 0.90947
# 665/665 [==============================] - 240s 361ms/step - loss: 0.1272 - accuracy: 0.9551 - val_loss: 0.3660 - val_accuracy: 0.8865
# Epoch 18/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1107 - accuracy: 0.9620
# Epoch 18: val_accuracy did not improve from 0.90947
# 665/665 [==============================] - 240s 361ms/step - loss: 0.1107 - accuracy: 0.9620 - val_loss: 1.2264 - val_accuracy: 0.7301
# Epoch 19/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9643
# Epoch 19: val_accuracy did not improve from 0.90947
# 665/665 [==============================] - 241s 362ms/step - loss: 0.1049 - accuracy: 0.9643 - val_loss: 0.3783 - val_accuracy: 0.8852
# Epoch 20/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1115 - accuracy: 0.9619
# Epoch 20: val_accuracy did not improve from 0.90947
# 665/665 [==============================] - 239s 359ms/step - loss: 0.1115 - accuracy: 0.9619 - val_loss: 0.9549 - val_accuracy: 0.7867
# Epoch 21/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9648
# Epoch 21: val_accuracy did not improve from 0.90947
# 665/665 [==============================] - 239s 360ms/step - loss: 0.1049 - accuracy: 0.9648 - val_loss: 0.5241 - val_accuracy: 0.8718
# Epoch 22/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1126 - accuracy: 0.9617
# Epoch 22: val_accuracy improved from 0.90947 to 0.91511, saving model to model_100_class.h5
# 665/665 [==============================] - 240s 360ms/step - loss: 0.1126 - accuracy: 0.9617 - val_loss: 0.3369 - val_accuracy: 0.9151
# Epoch 23/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1131 - accuracy: 0.9626
# Epoch 23: val_accuracy did not improve from 0.91511
# 665/665 [==============================] - 239s 359ms/step - loss: 0.1131 - accuracy: 0.9626 - val_loss: 0.3863 - val_accuracy: 0.8927
# Epoch 24/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1004 - accuracy: 0.9661
# Epoch 24: val_accuracy did not improve from 0.91511
# 665/665 [==============================] - 239s 359ms/step - loss: 0.1004 - accuracy: 0.9661 - val_loss: 0.4337 - val_accuracy: 0.8600
# Epoch 25/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0987 - accuracy: 0.9664
# Epoch 25: val_accuracy did not improve from 0.91511
# 665/665 [==============================] - 239s 360ms/step - loss: 0.0987 - accuracy: 0.9664 - val_loss: 0.4479 - val_accuracy: 0.8754
# Epoch 26/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1055 - accuracy: 0.9650
# Epoch 26: val_accuracy improved from 0.91511 to 0.91681, saving model to model_100_class.h5
# 665/665 [==============================] - 233s 351ms/step - loss: 0.1055 - accuracy: 0.9650 - val_loss: 0.3031 - val_accuracy: 0.9168
# Epoch 27/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1040 - accuracy: 0.9653
# Epoch 27: val_accuracy did not improve from 0.91681
# 665/665 [==============================] - 232s 349ms/step - loss: 0.1040 - accuracy: 0.9653 - val_loss: 0.6606 - val_accuracy: 0.8442
# Epoch 28/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0999 - accuracy: 0.9660
# Epoch 28: val_accuracy did not improve from 0.91681
# 665/665 [==============================] - 230s 345ms/step - loss: 0.0999 - accuracy: 0.9660 - val_loss: 0.5348 - val_accuracy: 0.8581
# Epoch 29/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0952 - accuracy: 0.9673
# Epoch 29: val_accuracy did not improve from 0.91681
# 665/665 [==============================] - 230s 346ms/step - loss: 0.0952 - accuracy: 0.9673 - val_loss: 0.4027 - val_accuracy: 0.8822
# Epoch 30/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.9663
# Epoch 30: val_accuracy did not improve from 0.91681
# 665/665 [==============================] - 229s 345ms/step - loss: 0.0994 - accuracy: 0.9663 - val_loss: 0.9188 - val_accuracy: 0.7527
# Epoch 31/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0951 - accuracy: 0.9664
# Epoch 31: val_accuracy did not improve from 0.91681
# 665/665 [==============================] - 230s 346ms/step - loss: 0.0951 - accuracy: 0.9664 - val_loss: 0.5752 - val_accuracy: 0.8421
# Epoch 32/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0890 - accuracy: 0.9700
# Epoch 32: val_accuracy did not improve from 0.91681
# 665/665 [==============================] - 345s 518ms/step - loss: 0.0890 - accuracy: 0.9700 - val_loss: 0.3847 - val_accuracy: 0.8970
# Epoch 33/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0991 - accuracy: 0.9671
# Epoch 33: val_accuracy did not improve from 0.91681
# 665/665 [==============================] - 264s 396ms/step - loss: 0.0991 - accuracy: 0.9671 - val_loss: 0.4937 - val_accuracy: 0.8660
# Epoch 34/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0841 - accuracy: 0.9720
# Epoch 34: val_accuracy did not improve from 0.91681
# 665/665 [==============================] - 304s 457ms/step - loss: 0.0841 - accuracy: 0.9720 - val_loss: 0.3357 - val_accuracy: 0.9145
# Epoch 35/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0927 - accuracy: 0.9696
# Epoch 35: val_accuracy did not improve from 0.91681
# 665/665 [==============================] - 454s 682ms/step - loss: 0.0927 - accuracy: 0.9696 - val_loss: 0.3351 - val_accuracy: 0.9066
# Epoch 36/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0819 - accuracy: 0.9720
# Epoch 36: val_accuracy did not improve from 0.91681
# 665/665 [==============================] - 258s 387ms/step - loss: 0.0819 - accuracy: 0.9720 - val_loss: 0.5584 - val_accuracy: 0.8583
# Epoch 37/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1059 - accuracy: 0.9665
# Epoch 37: val_accuracy did not improve from 0.91681
# 665/665 [==============================] - 255s 383ms/step - loss: 0.1059 - accuracy: 0.9665 - val_loss: 0.4970 - val_accuracy: 0.8632
# Epoch 38/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0981 - accuracy: 0.9668
# Epoch 38: val_accuracy did not improve from 0.91681
# 665/665 [==============================] - 264s 397ms/step - loss: 0.0981 - accuracy: 0.9668 - val_loss: 0.4834 - val_accuracy: 0.8763
# Epoch 39/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0880 - accuracy: 0.9708
# Epoch 39: val_accuracy did not improve from 0.91681
# 665/665 [==============================] - 257s 386ms/step - loss: 0.0880 - accuracy: 0.9708 - val_loss: 0.3199 - val_accuracy: 0.9098
# Epoch 40/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0872 - accuracy: 0.9707
# Epoch 40: val_accuracy did not improve from 0.91681
# 665/665 [==============================] - 281s 422ms/step - loss: 0.0872 - accuracy: 0.9707 - val_loss: 0.4362 - val_accuracy: 0.8891
# Epoch 41/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0950 - accuracy: 0.9673
# Epoch 41: val_accuracy did not improve from 0.91681
# 665/665 [==============================] - 284s 426ms/step - loss: 0.0950 - accuracy: 0.9673 - val_loss: 0.4949 - val_accuracy: 0.8735
# Epoch 42/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0888 - accuracy: 0.9708
# Epoch 42: val_accuracy did not improve from 0.91681
# 665/665 [==============================] - 252s 378ms/step - loss: 0.0888 - accuracy: 0.9708 - val_loss: 0.7987 - val_accuracy: 0.8216
# Epoch 43/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0881 - accuracy: 0.9719
# Epoch 43: val_accuracy did not improve from 0.91681
# 665/665 [==============================] - 230s 346ms/step - loss: 0.0881 - accuracy: 0.9719 - val_loss: 0.6859 - val_accuracy: 0.8263
# Epoch 44/100
# 665/665 [==============================] - ETA: 0s - loss: 0.1059 - accuracy: 0.9658
# Epoch 44: val_accuracy improved from 0.91681 to 0.93111, saving model to model_100_class.h5
# 665/665 [==============================] - 234s 352ms/step - loss: 0.1059 - accuracy: 0.9658 - val_loss: 0.2344 - val_accuracy: 0.9311
# Epoch 45/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0833 - accuracy: 0.9722
# Epoch 45: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 230s 346ms/step - loss: 0.0833 - accuracy: 0.9722 - val_loss: 0.2906 - val_accuracy: 0.9191
# Epoch 46/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0818 - accuracy: 0.9726
# Epoch 46: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 232s 348ms/step - loss: 0.0818 - accuracy: 0.9726 - val_loss: 0.5975 - val_accuracy: 0.8562
# Epoch 47/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0850 - accuracy: 0.9724
# Epoch 47: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 230s 346ms/step - loss: 0.0850 - accuracy: 0.9724 - val_loss: 0.5939 - val_accuracy: 0.8530
# Epoch 48/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0824 - accuracy: 0.9730
# Epoch 48: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 230s 346ms/step - loss: 0.0824 - accuracy: 0.9730 - val_loss: 45.7219 - val_accuracy: 0.2238
# Epoch 49/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0916 - accuracy: 0.9693
# Epoch 49: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 232s 349ms/step - loss: 0.0916 - accuracy: 0.9693 - val_loss: 0.3522 - val_accuracy: 0.8937
# Epoch 50/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0838 - accuracy: 0.9735
# Epoch 50: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 234s 352ms/step - loss: 0.0838 - accuracy: 0.9735 - val_loss: 1.7225 - val_accuracy: 0.6894
# Epoch 51/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0796 - accuracy: 0.9742
# Epoch 51: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 234s 352ms/step - loss: 0.0796 - accuracy: 0.9742 - val_loss: 0.6776 - val_accuracy: 0.8289
# Epoch 52/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0859 - accuracy: 0.9713
# Epoch 52: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 232s 349ms/step - loss: 0.0859 - accuracy: 0.9713 - val_loss: 0.7864 - val_accuracy: 0.7913
# Epoch 53/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0912 - accuracy: 0.9698
# Epoch 53: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 231s 348ms/step - loss: 0.0912 - accuracy: 0.9698 - val_loss: 1.1269 - val_accuracy: 0.7485
# Epoch 54/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9754
# Epoch 54: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 233s 350ms/step - loss: 0.0758 - accuracy: 0.9754 - val_loss: 0.5413 - val_accuracy: 0.8750
# Epoch 55/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0785 - accuracy: 0.9739
# Epoch 55: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 233s 351ms/step - loss: 0.0785 - accuracy: 0.9739 - val_loss: 0.3564 - val_accuracy: 0.8989
# Epoch 56/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0800 - accuracy: 0.9736
# Epoch 56: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 234s 351ms/step - loss: 0.0800 - accuracy: 0.9736 - val_loss: 0.3059 - val_accuracy: 0.9134
# Epoch 57/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0827 - accuracy: 0.9738
# Epoch 57: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 232s 349ms/step - loss: 0.0827 - accuracy: 0.9738 - val_loss: 0.3394 - val_accuracy: 0.8993
# Epoch 58/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9744
# Epoch 58: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 231s 348ms/step - loss: 0.0738 - accuracy: 0.9744 - val_loss: 0.3876 - val_accuracy: 0.8999
# Epoch 59/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0744 - accuracy: 0.9755
# Epoch 59: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 232s 348ms/step - loss: 0.0744 - accuracy: 0.9755 - val_loss: 1.9186 - val_accuracy: 0.6428
# Epoch 60/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.9676
# Epoch 60: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 233s 350ms/step - loss: 0.0994 - accuracy: 0.9676 - val_loss: 2.3742 - val_accuracy: 0.6480
# Epoch 61/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0717 - accuracy: 0.9773
# Epoch 61: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 232s 348ms/step - loss: 0.0717 - accuracy: 0.9773 - val_loss: 0.4323 - val_accuracy: 0.8794
# Epoch 62/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0683 - accuracy: 0.9780
# Epoch 62: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 232s 348ms/step - loss: 0.0683 - accuracy: 0.9780 - val_loss: 1.2382 - val_accuracy: 0.7773
# Epoch 63/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0704 - accuracy: 0.9758
# Epoch 63: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 345ms/step - loss: 0.0704 - accuracy: 0.9758 - val_loss: 1.1731 - val_accuracy: 0.7382
# Epoch 64/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0836 - accuracy: 0.9725
# Epoch 64: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 345ms/step - loss: 0.0836 - accuracy: 0.9725 - val_loss: 0.2902 - val_accuracy: 0.9177
# Epoch 65/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9775
# Epoch 65: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 344ms/step - loss: 0.0678 - accuracy: 0.9775 - val_loss: 0.8569 - val_accuracy: 0.8199
# Epoch 66/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0704 - accuracy: 0.9770
# Epoch 66: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 230s 346ms/step - loss: 0.0704 - accuracy: 0.9770 - val_loss: 0.4938 - val_accuracy: 0.8850
# Epoch 67/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9753
# Epoch 67: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 230s 346ms/step - loss: 0.0770 - accuracy: 0.9753 - val_loss: 1.8288 - val_accuracy: 0.6891
# Epoch 68/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0690 - accuracy: 0.9776
# Epoch 68: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 344ms/step - loss: 0.0690 - accuracy: 0.9776 - val_loss: 0.8320 - val_accuracy: 0.8315
# Epoch 69/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0645 - accuracy: 0.9784
# Epoch 69: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 344ms/step - loss: 0.0645 - accuracy: 0.9784 - val_loss: 0.4144 - val_accuracy: 0.9149
# Epoch 70/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0658 - accuracy: 0.9787
# Epoch 70: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 230s 346ms/step - loss: 0.0658 - accuracy: 0.9787 - val_loss: 0.3691 - val_accuracy: 0.9100
# Epoch 71/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0767 - accuracy: 0.9750
# Epoch 71: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 344ms/step - loss: 0.0767 - accuracy: 0.9750 - val_loss: 0.3291 - val_accuracy: 0.9104
# Epoch 72/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0660 - accuracy: 0.9783
# Epoch 72: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 344ms/step - loss: 0.0660 - accuracy: 0.9783 - val_loss: 0.3624 - val_accuracy: 0.9004
# Epoch 73/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0599 - accuracy: 0.9800
# Epoch 73: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 345ms/step - loss: 0.0599 - accuracy: 0.9800 - val_loss: 0.6582 - val_accuracy: 0.8423
# Epoch 74/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0719 - accuracy: 0.9770
# Epoch 74: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 230s 345ms/step - loss: 0.0719 - accuracy: 0.9770 - val_loss: 0.3637 - val_accuracy: 0.9059
# Epoch 75/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0682 - accuracy: 0.9780
# Epoch 75: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 345ms/step - loss: 0.0682 - accuracy: 0.9780 - val_loss: 0.4563 - val_accuracy: 0.8810
# Epoch 76/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0637 - accuracy: 0.9794
# Epoch 76: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 344ms/step - loss: 0.0637 - accuracy: 0.9794 - val_loss: 0.2710 - val_accuracy: 0.9264
# Epoch 77/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9740
# Epoch 77: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 228s 343ms/step - loss: 0.0831 - accuracy: 0.9740 - val_loss: 0.2974 - val_accuracy: 0.9202
# Epoch 78/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0741 - accuracy: 0.9781
# Epoch 78: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 344ms/step - loss: 0.0741 - accuracy: 0.9781 - val_loss: 0.4513 - val_accuracy: 0.8901
# Epoch 79/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9792
# Epoch 79: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 228s 343ms/step - loss: 0.0627 - accuracy: 0.9792 - val_loss: 0.3395 - val_accuracy: 0.9179
# Epoch 80/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0655 - accuracy: 0.9794
# Epoch 80: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 344ms/step - loss: 0.0655 - accuracy: 0.9794 - val_loss: 0.4025 - val_accuracy: 0.8937
# Epoch 81/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0664 - accuracy: 0.9788
# Epoch 81: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 344ms/step - loss: 0.0664 - accuracy: 0.9788 - val_loss: 1.2758 - val_accuracy: 0.7700
# Epoch 82/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0721 - accuracy: 0.9759
# Epoch 82: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 344ms/step - loss: 0.0721 - accuracy: 0.9759 - val_loss: 0.3540 - val_accuracy: 0.9016
# Epoch 83/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0606 - accuracy: 0.9803
# Epoch 83: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 344ms/step - loss: 0.0606 - accuracy: 0.9803 - val_loss: 0.4758 - val_accuracy: 0.8858
# Epoch 84/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0670 - accuracy: 0.9792
# Epoch 84: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 232s 349ms/step - loss: 0.0670 - accuracy: 0.9792 - val_loss: 0.6800 - val_accuracy: 0.8457
# Epoch 85/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0681 - accuracy: 0.9782
# Epoch 85: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 230s 346ms/step - loss: 0.0681 - accuracy: 0.9782 - val_loss: 0.3467 - val_accuracy: 0.9159
# Epoch 86/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0562 - accuracy: 0.9816
# Epoch 86: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 230s 345ms/step - loss: 0.0562 - accuracy: 0.9816 - val_loss: 0.4121 - val_accuracy: 0.8929
# Epoch 87/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0989 - accuracy: 0.9692
# Epoch 87: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 345ms/step - loss: 0.0989 - accuracy: 0.9692 - val_loss: 0.3077 - val_accuracy: 0.9170
# Epoch 88/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0660 - accuracy: 0.9779
# Epoch 88: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 344ms/step - loss: 0.0660 - accuracy: 0.9779 - val_loss: 0.2865 - val_accuracy: 0.9255
# Epoch 89/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9806
# Epoch 89: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 344ms/step - loss: 0.0643 - accuracy: 0.9806 - val_loss: 0.4566 - val_accuracy: 0.8899
# Epoch 90/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0595 - accuracy: 0.9808
# Epoch 90: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 345ms/step - loss: 0.0595 - accuracy: 0.9808 - val_loss: 0.5781 - val_accuracy: 0.8705
# Epoch 91/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0720 - accuracy: 0.9765
# Epoch 91: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 344ms/step - loss: 0.0720 - accuracy: 0.9765 - val_loss: 0.2982 - val_accuracy: 0.9302
# Epoch 92/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0689 - accuracy: 0.9785
# Epoch 92: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 344ms/step - loss: 0.0689 - accuracy: 0.9785 - val_loss: 0.5629 - val_accuracy: 0.8803
# Epoch 93/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0664 - accuracy: 0.9790
# Epoch 93: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 231s 348ms/step - loss: 0.0664 - accuracy: 0.9790 - val_loss: 0.5490 - val_accuracy: 0.8716
# Epoch 94/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0586 - accuracy: 0.9813
# Epoch 94: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 230s 345ms/step - loss: 0.0586 - accuracy: 0.9813 - val_loss: 0.4343 - val_accuracy: 0.8897
# Epoch 95/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0708 - accuracy: 0.9779
# Epoch 95: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 228s 343ms/step - loss: 0.0708 - accuracy: 0.9779 - val_loss: 0.2976 - val_accuracy: 0.9230
# Epoch 96/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0763 - accuracy: 0.9754
# Epoch 96: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 230s 345ms/step - loss: 0.0763 - accuracy: 0.9754 - val_loss: 0.2775 - val_accuracy: 0.9264
# Epoch 97/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.9801
# Epoch 97: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 228s 343ms/step - loss: 0.0598 - accuracy: 0.9801 - val_loss: 0.2981 - val_accuracy: 0.9200
# Epoch 98/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0579 - accuracy: 0.9810
# Epoch 98: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 230s 345ms/step - loss: 0.0579 - accuracy: 0.9810 - val_loss: 0.2739 - val_accuracy: 0.9294
# Epoch 99/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0577 - accuracy: 0.9812
# Epoch 99: val_accuracy did not improve from 0.93111
# 665/665 [==============================] - 229s 344ms/step - loss: 0.0577 - accuracy: 0.9812 - val_loss: 0.4472 - val_accuracy: 0.8859
# Epoch 100/100
# 665/665 [==============================] - ETA: 0s - loss: 0.0691 - accuracy: 0.9787
# Epoch 100: val_accuracy improved from 0.93111 to 0.93337, saving model to model_100_class.h5
# 665/665 [==============================] - 230s 345ms/step - loss: 0.0691 - accuracy: 0.9787 - val_loss: 0.2880 - val_accuracy: 0.9334

# %%
# [+] inform the user with model Accuracy %
scores = model.evaluate(X_test, y_test, verbose = 1)
print("Accuracy: %.2f%%" % (scores[1] * 100))
# Out:
# 167/167 [==============================] - 7s 41ms/step - loss: 0.2880 - accuracy: 0.9334
# Accuracy: 93.34%

# %%
def display_accuracy() -> None:
    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['accuracy', 'val_accuracy'], loc='upper left')
    plt.show()

def display_loss() -> None:
    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

display_accuracy()
display_loss()

# %%
y_pred = model.predict(X_test)

def test_model() -> tuple:
    """ Tunning the accurate results and inaccurate results

    Returns:
        (total, accurate) [tuple]: tuple of total tested test-cases, accurate
    """
    total = 0
    accurate = 0
    accurateindex = []
    wrongindex = []
    for i in range(len(y_pred)):
        if np.argmax(y_pred[i]) == np.argmax(y_test[i]):
            accurate += 1
            accurateindex.append(i)
        else:
            wrongindex.append(i)
        total += 1
    return (total, accurate)

total, accurate = test_model()
print('Total-test-data;', total, '\taccurately-predicted-data:', accurate, '\t wrongly-predicted-data: ', total - accurate)
print('Accuracy:', round(accurate / total * 100, 3), '%')
# Out:
# 167/167 [==============================] - 8s 44ms/step
# Total-test-data; 5313 	accurately-predicted-data: 4959 	 wrongly-predicted-data:  354
# Accuracy: 93.337 %

# %% [markdown]
# **this was the model we got from epoch 100...
# Now we will see the best model saved before finishing the training..**

# %%
best_model = load_model('./model_100_class.h5')

# Compute predictions
y_pred_prob = np.around(best_model.predict(X_test),3)
y_pred = np.argmax(y_pred_prob, axis = 1)
y_test2 = np.argmax(y_test, axis = 1)
# Out:
# 167/167 [==============================] - 17s 99ms/step

# %%
# [+] inform the user with model Accuracy %
scores = best_model.evaluate(X_test, y_test, verbose = 1)
print("Accuracy: %.2f%%" % (scores[1] * 100))
# Out:
# 167/167 [==============================] - 18s 97ms/step - loss: 0.2880 - accuracy: 0.9334
# Accuracy: 93.34%

# %%
plt.figure(figsize=(16,16))
for i in range(16):
    plt.subplot(4,4,i+1)
    index = i+100
    plt.imshow(X_test[index,:,:,::-1])
    label_exp = lesion_names[y_test2[index]]  #expected label
    label_pred = lesion_names[y_pred[index]]  #predicted label
    label_pred_prob = round(np.max(y_pred_prob[index])*100)
    plt.title('Expected:'+str(label_exp)+'\n Pred.:'+str(label_pred)+' ('+str(label_pred_prob)+'%)')
plt.ylabel('')
plt.tight_layout()
plt.savefig('final_figure.png',dpi=300)
plt.show()

# %%
#Accuracy for each type
acc_tot= []

for i in range(7):
    acc_parz = round(np.mean(y_test2[y_test2 == i] == y_pred[y_test2 == i]),2)
    lab_parz = lesion_names[i]
    print('accuracy for',lab_parz,'=',acc_parz)
    acc_tot.append(acc_parz)
# Out:
# accuracy for Melanocytic nevi = 0.87
# accuracy for Melanoma = 0.96
# accuracy for Benign keratosis-like lesions  = 0.96
# accuracy for Basal cell carcinoma = 0.96
# accuracy for Actinic keratoses = 0.93
# accuracy for Vascular lesions = 0.98
# accuracy for Dermatofibroma = 0.93

# %%
acc_tot = np.array(acc_tot)
freq = np.unique(y_test2,return_counts=True)[1]

np.sum(acc_tot*freq)/np.sum(freq)
# Out:
# 0.9349313005834746
